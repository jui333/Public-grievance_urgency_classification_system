# %% [markdown]
# # Grievance Data Exploration
#
# This notebook loads the grievance dataset, inspects complaint categories, and evaluates urgency label behavior.

# %%
import pandas as pd
from backend.preprocessing import create_text_feature, create_target_label, map_urgency_label

data_path = '../no_pii_grievance.json'
df = pd.read_json(data_path)
print(df.shape)
df = create_text_feature(df)
df = create_target_label(df)
df = map_urgency_label(df)
df[['complaint_text_clean', 'category_label', 'urgency_label']].head()
